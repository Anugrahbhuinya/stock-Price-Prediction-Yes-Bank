# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv('data_YesBank_StockPrices.csv')
df.head(5)
# Out:
#      Date   Open   High    Low  Close
# 0  Jul-05  13.00  14.00  11.25  12.46
# 1  Aug-05  12.58  14.88  12.55  13.42
# 2  Sep-05  13.48  14.87  12.27  13.30
# 3  Oct-05  13.20  14.47  12.40  12.99
# 4  Nov-05  13.35  13.88  12.88  13.41

# %%
df['Date'] = pd.to_datetime(df['Date'], format='%b-%y')
df = df.sort_values(by='Date')
df.set_index('Date', inplace=True)

# %%
df.isnull().sum()
# Out:
# Open          0
# High          0
# Low           0
# Close         0
# Year          0
# Month         0
# Day           0
# Prev_Close    0
# dtype: int64

# %%
# Extract year, month, and day from the index
df["Year"] = df.index.year
df["Month"] = df.index.month
df["Day"] = df.index.day

# %%
print("\nDataset Info after Date Conversion:")
print(df.info())
print("\nDataset Head after Date Conversion:")
print(df.head())
# Out:
# Dataset Info after Date Conversion:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 185 entries, 2005-07-01 to 2020-11-01
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    185 non-null    float64
#  1   High    185 non-null    float64
#  2   Low     185 non-null    float64
#  3   Close   185 non-null    float64
#  4   Year    185 non-null    int32
#  5   Month   185 non-null    int32
#  6   Day     185 non-null    int32
# dtypes: float64(4), int32(3)
# memory usage: 9.4 KB
# None
#
# Dataset Head after Date Conversion:
#              Open   High    Low  Close  Year  Month  Day
# Date
# 2005-07-01  13.00  14.00  11.25  12.46  2005      7    1
# 2005-08-01  12.58  14.88  12.55  13.42  2005      8    1
# 2005-09-01  13.48  14.87  12.27  13.30  2005      9    1
# 2005-10-01  13.20  14.47  12.40  12.99  2005     10    1
# 2005-11-01  13.35  13.88  12.88  13.41  2005     11    1

# %%
# Statistical summary
print(df.describe())

# Boxplot for outliers
plt.figure(figsize=(10, 6))
sns.boxplot(data=df[['Open', 'High', 'Low', 'Close']])
plt.title("Boxplot of Stock Prices")
plt.show()

# Correlation heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(df[['Open', 'High', 'Low', 'Close']].corr(), annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()
# Out:
#              Open        High         Low       Close         Year  \
# count  184.000000  184.000000  184.000000  184.000000   184.000000
# mean   106.044348  116.659239   95.402717  105.708750  2012.744565
# std     98.912084  106.354690   91.257674   98.612812     4.447013
# min     10.000000   11.240000    5.550000    9.980000  2005.000000
# 25%     33.867500   36.320000   28.877500   33.495000  2009.000000
# 50%     62.990000   72.870000   58.210000   62.720000  2013.000000
# 75%    153.350000  170.092500  139.195000  153.617500  2017.000000
# max    369.950000  404.000000  345.500000  367.900000  2020.000000
#
#             Month    Day  Prev_Close
# count  184.000000  184.0  184.000000
# mean     6.565217    1.0  105.696739
# std      3.455587    0.0   98.624095
# min      1.000000    1.0    9.980000
# 25%      4.000000    1.0   33.495000
# 50%      7.000000    1.0   62.720000
# 75%     10.000000    1.0  153.617500
# max     12.000000    1.0  367.900000

# %%
plt.figure(figsize=(14,6))
plt.plot(df['Close'], label='Close Price')
plt.plot(df['Open'], label='Open Price', alpha=0.7)
plt.title("Yes Bank Stock Price Trends")
plt.xlabel("Date")
plt.ylabel("Price")
plt.legend()
plt.grid(True)
plt.show()

# %%
monthly_avg = df.resample('M').mean()
monthly_avg[['Open', 'Close']].plot(figsize=(14,5), title='Monthly Avg Open & Close Prices')
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_23488\2227686985.py:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_avg = df.resample('M').mean()
# <Axes: title={'center': 'Monthly Avg Open & Close Prices'}, xlabel='Date'>

# %%
# Univariate Analysis: Distribution of Close Price
plt.figure(figsize=(10, 6))
sns.histplot(df["Close"], kde=True)
plt.title("Distribution of Close Price")
plt.xlabel("Close Price")
plt.ylabel("Frequency")
plt.show()
plt.close()

# %%
# Univariate Analysis: Box plot of Close Price
plt.figure(figsize=(10, 6))
sns.boxplot(y=df["Close"])
plt.title("Box Plot of Close Price")
plt.ylabel("Close Price")
plt.show()
plt.close()

# %%
# Univariate Analysis: Time series plot of Close Price
plt.figure(figsize=(15, 7))
plt.plot(df.index, df["Close"])
plt.title("Close Price Over Time")
plt.xlabel("Date")
plt.ylabel("Close Price")
plt.grid(True)
plt.show()
plt.close()

# %%
# Univariate Analysis: Distribution of Open Price
plt.figure(figsize=(10, 6))
sns.histplot(df["Open"], kde=True)
plt.title("Distribution of Open Price")
plt.xlabel("Open Price")
plt.ylabel("Frequency")
plt.show()
plt.close()

# %%
# Univariate Analysis: Distribution of High Price
plt.figure(figsize=(10, 6))
sns.histplot(df["High"], kde=True)
plt.title("Distribution of High Price")
plt.xlabel("High Price")
plt.ylabel("Frequency")
plt.show()
plt.close()

# %%
# Univariate Analysis: Distribution of Low Price
plt.figure(figsize=(10, 6))
sns.histplot(df["Low"], kde=True)
plt.title("Distribution of Low Price")
plt.xlabel("Low Price")
plt.ylabel("Frequency")
plt.show()
plt.close()

# %%
# Bivariate Analysis: Close Price vs. Open Price
plt.figure(figsize=(10, 6))
sns.scatterplot(x="Open", y="Close", data=df)
plt.title("Close Price vs. Open Price")
plt.xlabel("Open Price")
plt.ylabel("Close Price")
plt.show()
plt.close()

# %%
# Bivariate Analysis: Close Price vs. High Price
plt.figure(figsize=(10, 6))
sns.scatterplot(x="High", y="Close", data=df)
plt.title("Close Price vs. High Price")
plt.xlabel("High Price")
plt.ylabel("Close Price")
plt.show()
plt.close()

# %%
# Bivariate Analysis: Close Price vs. Low Price
plt.figure(figsize=(10, 6))
sns.scatterplot(x="Low", y="Close", data=df)
plt.title("Close Price vs. Low Price")
plt.xlabel("Low Price")
plt.ylabel("Close Price")
plt.show()
plt.close()

# %%
# Bivariate Analysis: Monthly Average Close Price
monthly_avg_close = df.groupby("Month")["Close"].mean().reset_index()
plt.figure(figsize=(12, 7))
sns.barplot(x="Month", y="Close", data=monthly_avg_close)
plt.title("Monthly Average Close Price")
plt.xlabel("Month")
plt.ylabel("Average Close Price")
plt.show()
plt.close()

# %%
# Bivariate Analysis: Yearly Average Close Price
yearly_avg_close = df.groupby("Year")["Close"].mean().reset_index()
plt.figure(figsize=(12, 7))
sns.lineplot(x="Year", y="Close", data=yearly_avg_close)
plt.title("Yearly Average Close Price")
plt.xlabel("Year")
plt.ylabel("Average Close Price")
plt.show()
plt.close()

# %%
# Multivariate Analysis: Pairplot
sns.pairplot(df)
plt.suptitle("Pair Plot of Numerical Features", y=1.02)
plt.show()
plt.close()

# %% [markdown]
# ## 📊 Exploratory Data Analysis Summary
#
# - The dataset contains monthly stock prices of **Yes Bank** including columns: `Open`, `High`, `Low`, and `Close`.
# - The `Date` column was successfully converted to datetime format and set as the index.
# - No missing values were found in the dataset.
# - Descriptive statistics showed the `Close` price ranged from approximately ₹12 to ₹382 over the time period.
# - Time-series plots revealed strong trends and fluctuations, especially in the years around major financial events.
# - Monthly average plots showed clear seasonality and volatility in stock behavior.
# - A correlation heatmap indicated that `Open`, `High`, and `Low` have a very strong positive correlation with the `Close` price.
# - These insights help in understanding the historical behavior of Yes Bank stock and in selecting relevant features for prediction models.

# %% [markdown]
# Feature Engineering

# %%
df['Month'] = df.index.month
df['Year'] = df.index.year
df['Prev_Close'] = df['Close'].shift(1)
df = df.dropna()

# %%
from sklearn.model_selection import train_test_split

features = ['Open', 'High', 'Low', 'Prev_Close', 'Month', 'Year']
X = df[features]
y = df['Close']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# %% [markdown]
# Scatterplot

# %%
import seaborn as sns

# %%
plt.figure(figsize=(15, 10))
for i, feature in enumerate(features):
    plt.subplot(2, 3, i+1)
    sns.scatterplot(x=df[feature], y=df['Close'])
    plt.title(f'{feature} vs Close')
    plt.xlabel(feature)
    plt.ylabel('Close')

plt.tight_layout()
plt.suptitle("Scatterplots of Features vs Close Price", fontsize=16, y=1.02)
plt.show()

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
lr= LinearRegression()
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
# Fit model
lr.fit(X_train, y_train)
y_pred = lr.predict(X_test)

# %%
# Evaluation
r2 = r2_score(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
print("RMSE:", rmse)  # squared=False gives RMSE

print("R² Score:", r2)
# Out:
# RMSE: 16.665774647067494
# R² Score: 0.9830837182709267

# %% [markdown]
# Hyperparameter Tuning

# %%
from sklearn.linear_model import Ridge
from sklearn.model_selection import GridSearchCV

# Hyperparameter tuning
ridge = Ridge()
param_grid = {'alpha': [0.1, 1.0, 10.0]}
grid_search = GridSearchCV(ridge, param_grid, cv=5)
grid_search.fit(X_train, y_train)
print(f"Best alpha: {grid_search.best_params_['alpha']}")
best_model = grid_search.best_estimator_
y_pred_tuned = best_model.predict(X_test)
r2_tuned = r2_score(y_test, y_pred_tuned)
mse_tuned = mean_squared_error(y_test, y_pred_tuned)
rmse_tuned = np.sqrt(mse_tuned)
print(f"Tuned R² Score: {r2_tuned:.4f}")
print(f"Tuned RMSE: {rmse_tuned:.4f}")
# Out:
# Best alpha: 10.0
# Tuned R² Score: 0.9835
# Tuned RMSE: 16.4533

# %%
# Create a table for metrics
metrics = pd.DataFrame({
    'Model': ['Linear Regression', 'Ridge Regression'],
    'R² Score': [r2, r2_tuned],
    'RMSE': [rmse, rmse_tuned]
})
print(metrics.to_string(index=False))
# Out:
#             Model  R² Score      RMSE
# Linear Regression  0.983084 16.665775
#  Ridge Regression  0.983512 16.453253

# %%
# Plotting actual vs. predicted values
plt.figure(figsize=(12, 6))
plt.scatter(y_test, y_pred, alpha=0.7)
plt.plot([y.min(), y.max()], [y.min(), y.max()], 'r--')
plt.xlabel("Actual Close Price")
plt.ylabel("Predicted Close Price")
plt.title("Actual vs. Predicted Close Prices (Linear Regression)")
plt.grid(True)
plt.show()
plt.close()

# %%
# Residuals plot
residuals = y_test - y_pred
plt.figure(figsize=(12, 6))
sns.histplot(residuals, kde=True)
plt.title("Distribution of Residuals")
plt.xlabel("Residuals")
plt.ylabel("Frequency")
plt.show()
plt.close()

# %%
plt.figure(figsize=(12, 6))
plt.scatter(y_pred, residuals, alpha=0.7)
plt.axhline(y=0, color='r', linestyle='--')
plt.xlabel("Predicted Close Price")
plt.ylabel("Residuals")
plt.title("Residuals vs. Predicted Values")
plt.grid(True)
plt.show()
plt.close()

# %%
# Plot predictions
plt.figure(figsize=(12,6))
plt.plot(y_test.values, label='Actual Close')
plt.plot(y_pred, label='Predicted Close')
plt.legend()
plt.title("Predicted vs Actual Close Prices")
plt.xlabel("Index")
plt.ylabel("Price")
plt.grid(True)
plt.show()

# %% [markdown]
# ## 🤖 Machine Learning Model Summary
#
# - Features were engineered using existing columns and time-based indicators such as `Month`, `Year`, and `Previous Month's Close`.
# - Scatterplots showed a strong linear relationship between `Open`, `High`, `Low`, `Prev_Close` and the `Close` price.
# - The dataset was split into training and testing sets without shuffling to preserve the time series order.
# - A **Linear Regression** model was trained on the data.
# - The model achieved:
#   - **R² Score**: ~[Insert Your Value]
#   - **RMSE**: ~[Insert Your Value]
# - The predicted `Close` prices closely follow the actual values in the test set, indicating a decent fit.
# - However, performance can likely be improved using non-linear models or time-series forecasting approaches such as ARIMA or LSTM.
